# %%
import pandas as pd

df = pd.read_csv(
    "../data stuff/augmented_telemetry.csv",
    dtype=str
)

df["valid_gps"] = df["valid_gps"].str.upper() == "TRUE"

df_valid = df[df["valid_gps"]]

output_path = "/Users/xDAyN/Desktop/Lifelines Hackathon/augmented_telemetry_filtered.csv"
df_valid.to_csv(output_path, index=False)

print(f"Saved filtered CSV with {len(df_valid)} rows to:")
print(output_path)
# Out:
# Saved filtered CSV with 73645 rows to:
# /Users/xDAyN/Desktop/Lifelines Hackathon/augmented_telemetry_filtered.csv
